# %%
import os
import gspread
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\computer world\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
load_dotenv()

current_working_dir = os.getcwd()
#project_json is the credential file for the service account created
project_json = os.getenv("PROJECT_JSON")
path = os.path.join(current_working_dir,project_json)

client = gspread.service_account(path)

spreadsheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1SUlcukpgxf6pfFQbj6DKQZXSlOhyBOSuBdbmQ2ZbhTM/edit?usp=sharing")
worksheet = spreadsheet.worksheet("inconsistent_data")

spreadsheet_data = worksheet.get_all_records()
spreadsheet_data[1]
# Out:
# {'S#': 2,
#  'Date': 'Monday-November 6-2000',
#  'Islamic Date': '10 SHa`baan 1421 A.H',
#  'Blast Day Type': 'Working Day',
#  'Holiday Type': '',
#  'Time': 'N/A',
#  'City': 'Karachi',
#  'Latitude': 24.9918,
#  'Longitude': 66.9911,
#  'Province': 'Sindh',
#  'Location': 'office of Nawa-e-Waqt',
#  'Location Category': 'Office Building',
#  'Location Sensitivity': 'Low',
#  'Open/Closed Space': 'Closed',
#  'Influencing Event/Event': '',
#  'Target Type': 'Media',
#  'Targeted Sect if any': 'None',
#  'Killed Min': '',
#  'Killed Max': 3,
#  'Injured Min': '',
#  'Injured Max': 3,
#  'No. of Suicide Blasts': 1,
#  'Explosive Weight (max)': '',
#  'Hospital Names': '',
#  'Temperature(C)': 23.77,
#  'Temperature(F)': 74.786}

# %%
data = pd.DataFrame(spreadsheet_data)
data
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                        ...                            ...
# 491  492   Thursday-October-05-2017           13 MuHarram 1439 A.H
# 492  493   Thursday-October-19-2017           27 MuHarram 1439 A.H
# 493  494   Thursday-November-9-2017              19 Safar 1439 A.H
# 494  495    Friday-November-24-2017       5 Rabi Al-Awwal 1439 A.H
# 495  496  Saturday-November-25-2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type Holiday Type         Time       City   Latitude  Longitude  \
# 0          Holiday      Weekend          N/A  Islamabad     33.718    73.0718
# ...

# %%
data['Holiday Type'].value_counts()
# Out:
#                                        424
# Weekend                                 45
# Ashura                                   4
# Eid Milad un-Nabi                        3
# Labour Day                               3
# Eid-ul-Fitar                             3
# Iqbal Day                                2
# Pakistan Day                             2
# Eid Holidays                             2
# Ashura Holiday                           2
# Christmas/birthday of Quaid-e-Azam       1
# Eid-ul-azha                              1
# Defence Day                              1
# Christmas/ birthday of Quaid-e-Azam      1
# General Elections                        1
# Eid ul Azha Holiday                      1
# Name: Holiday Type, dtype: int64

# %%
data
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                        ...                            ...
# 491  492   Thursday-October-05-2017           13 MuHarram 1439 A.H
# 492  493   Thursday-October-19-2017           27 MuHarram 1439 A.H
# 493  494   Thursday-November-9-2017              19 Safar 1439 A.H
# 494  495    Friday-November-24-2017       5 Rabi Al-Awwal 1439 A.H
# 495  496  Saturday-November-25-2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type Holiday Type         Time       City   Latitude  Longitude  \
# 0          Holiday      Weekend          N/A  Islamabad     33.718    73.0718
# ...

# %%
#replacing empty rows in column Holiday Type with category 'No Holiday'
data_ = data['Holiday Type'].replace('','No Holiday')
data_ = pd.concat([data.drop(columns='Holiday Type'),data_],axis=1)
data_
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                        ...                            ...
# 491  492   Thursday-October-05-2017           13 MuHarram 1439 A.H
# 492  493   Thursday-October-19-2017           27 MuHarram 1439 A.H
# 493  494   Thursday-November-9-2017              19 Safar 1439 A.H
# 494  495    Friday-November-24-2017       5 Rabi Al-Awwal 1439 A.H
# 495  496  Saturday-November-25-2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type         Time       City   Latitude  Longitude     Province  \
# 0          Holiday          N/A  Islamabad     33.718    73.0718      Capital
# ...

# %%
data_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S#                       496 non-null    int64
#  1   Date                     496 non-null    object
#  2   Islamic Date             496 non-null    object
#  3   Blast Day Type           496 non-null    object
#  4   Time                     496 non-null    object
#  5   City                     496 non-null    object
#  6   Latitude                 496 non-null    object
#  7   Longitude                496 non-null    object
#  8   Province                 496 non-null    object
#  9   Location                 496 non-null    object
#  10  Location Category        496 non-null    object
#  11  Location Sensitivity     496 non-null    object
#  12  Open/Closed Space        496 non-null    object
#  13  Influencing Event/Event  496 non-null    object
# ...

# %%
#working on Explosive weight (max) Column
data_['Explosive Weight (max)'] = data_['Explosive Weight (max)'].apply(lambda x : str(x).lower())
data_['Explosive Weight (max)'].unique()
# Out:
# array(['', '2.5 kg', 'na', '30kg in each car', '2kg', '10-15 kg', '5 kg',
#        '10 kg', '5 to 6 kg', '10 to 15 kg', 'more than 5kg', '15 kg',
#        '3 kg explosive and 3kg ball bearings', '6-7kg', '4-5kg', '50kg',
#        '30kg', '100kg', '150kg', '1000 kg', '8 kg', '60kg',
#        '8 ft deep crater', '40 kg', '7 or 8kg', '8kg', '100', '85',
#        '125 kg', '5kg', '160', '500 kg', '24kg', '10kg', '20 kg', '12kg',
#        '12 kg', '150 kg', '180kg', '100 kg', '70 kg', '16 kg', '15kg',
#        '7kg', '400kg', '200kg', '50-60kg', '250kg', '250 kg', '600 kg',
#        '40kg', '600kg', '14 kg', '300 kg', '20kg', '6 kg', '1200kg',
#        '400 kg', '9kg', '16kg', '16-20kg', '300kg', '450kg', '5-6kg',
#        '3kg', '6kg', 'n/a', '100-110kg', '7kg-8kg', '100kg-150kg',
#        '4kg-5kg', '600kg-800kg', '4kg-6kg', '1000kg', '#n/a', '7-8kg',
#        '20-25kg', '25-30kg', '14kg', '45kg', '13kg', '8-10kg', '8-10 kg',
#        '75kg', '25kg'], dtype=object)

# %%
#column inconsistency worked on, but results not accurate
data_['Explosive Weight (max)'].replace('[^0-9.]','',regex=True).unique()
# Out:
# array(['', '2.5', '30', '2', '1015', '5', '10', '56', '15', '33', '67',
#        '45', '50', '100', '150', '1000', '8', '60', '40', '78', '85',
#        '125', '160', '500', '24', '20', '12', '180', '70', '16', '7',
#        '400', '200', '5060', '250', '600', '14', '300', '6', '1200', '9',
#        '1620', '450', '3', '100110', '100150', '600800', '46', '2025',
#        '2530', '13', '810', '75', '25'], dtype=object)

# %%
data_['Time']
# Out:
# 0              N/A
# 1              N/A
# 2          7:45 AM
# 3      11:10:00 AM
# 4              N/A
#           ...
# 491
# 492        8:00 AM
# 493        7:00 AM
# 494        7:00 AM
# 495        7:00 AM
# Name: Time, Length: 496, dtype: object

# %%
data_['Time'].unique()
# Out:
# array(['N/A', '7:45 AM', '11:10:00 AM', '1:40:00 PM/1:42:00 PM', '',
#        '1:20:00/1:17:00 PM', 'evening', '8:50:PM', '7:20 PM',
#        '1:27 PM/1:25 PM', '5:55:00/6:40:00 PM', '11.45PM /10.30 pm',
#        '11:00:00 AM', '9:35:00 AM', '9:00:00 AM', '7.00 pm', '10.30 am',
#        '3:30:00 PM', '8.00 am', '8.30am', '7.30 am/7:15AM', '10:30:00 AM',
#        '2:37:00 PM', '8:40:00 PM', '6:17:00 AM', '12:15:00 PM',
#        '8:50:00 PM/9:10 PM', '11:05:00 AM', '11:45 AM', '6:55 PM',
#        '12:55:00 PM', 'About 12pm', '10:25am', '4:30:00 PM', '2:00:00 PM',
#        '3:30 PM-4:00:00 PM/4:15PM', 'between 7:00-7:40 AM', '8:27:00 AM',
#        '1:30:00 PM', '8:40:00 AM', '7:50:00 AM', '12:30:00 PM/11:00AM',
#        '5:25 PM', 'Night', '10:30am', 'NA', '10:00:00 AM', '7:15:00 AM',
#        '7:15:00 PM', '2:00:00 AM', '8:30:00 AM', '12:00 mid night',
#        '2:45:00 PM', '11:50:00 AM', '7:10:00 AM', '4:15:00 PM',
#        '7:40:00 AM', '11:15:00 AM/12:30 PM', '7:24:00 AM/7:30AM',
# ...

# %%
data_['Date'].unique()
# Out:
# array(['Sunday-November 19-1995', 'Monday-November 6-2000',
#        'Wednesday-May 8-2002', 'Friday-June 14-2002',
#        'Friday-July 4-2003', 'Thursday-December 25-2003',
#        'Saturday-February 28-2004', 'Friday-May 7-2004',
#        'Monday-May 31-2004', 'Thursday-June 3-2004',
#        'Wednesday-July 28-2004', 'Friday-July 30-2004',
#        'Friday-October 1-2004', 'Sunday-October 10-2004',
#        'Saturday-March 19-2005', 'Thursday-April 28-2005',
#        'Friday-May 27-2005', 'Monday-May 30-2005',
#        'Thursday-February 9-2006', 'Thursday-March 2-2006',
#        'Wednesday-April 12-2006', 'Friday-June 2-2006',
#        'Monday-June 26-2006', 'Sunday-August 6-2006',
#        'Wednesday-November 8-2006', 'Friday-November 17-2006',
#        'Sunday-December 3-2006', 'Monday-January 22-2007',
#        'Friday-January 26-2007', 'Saturday-January 27-2007',
#        'Monday-January 29-2007', 'Saturday-February 3-2007',
# ...

# %%
#splitting Date column and synthesizing four columns from it
data_[['Day_name','Month','Day_date','Year']] = data_['Date'].str.split('-',expand=True)

# %%
data_.loc[data_['Year'].isna(),'Month']
# Out:
# 0      November 19
# 1       November 6
# 2            May 8
# 3          June 14
# 4           July 4
#           ...
# 467         May 30
# 468         Aug 08
# 469         Sep 02
# 470         Sep 13
# 471         Sep 16
# Name: Month, Length: 469, dtype: object

# %% [markdown]
# Certain Rows are not in perfect order, leading to Year having month values and vice versa

# %%
#getting values for day and month 
day = data_.loc[data_['Year'].isna(),'Month'].str.split(' ',expand=True)[1]
month = data_.loc[data_['Year'].isna(),'Month'].str.split(' ',expand=True)[0]

# %%
month[455:]
# Out:
# 455    Oct
# 459    Jan
# 460    Jan
# 461    Jan
# 462    Feb
# 463    Mar
# 464    Mar
# 465    Apr
# 466    Apr
# 467    May
# 468    Aug
# 469    Sep
# 470    Sep
# 471    Sep
# Name: 0, dtype: object

# %%
#visualizing rows in Month column where year is not null
data_.loc[data_['Year'].notna(),'Month']
# Out:
# 456         Oct
# 457         Oct
# 458         Dec
# 472         Oct
# 473         Nov
# 474         Nov
# 475         Feb
# 476         Feb
# 477         Feb
# 478         Feb
# 479         Feb
# 480         Feb
# 481         Feb
# 482       April
# 483         May
# 484         May
# 485        June
# 486        July
# 487        July
# 488        July
# 489        July
# 490      August
# 491     October
# 492     October
# 493    November
# 494    November
# 495    November
# Name: Month, dtype: object

# %%
data_['Day_date']
# Out:
# 0      1995
# 1      2000
# 2      2002
# 3      2002
# 4      2003
#        ...
# 491      05
# 492      19
# 493       9
# 494      24
# 495      25
# Name: Day_date, Length: 496, dtype: object

# %%
data_.loc[data_['Year'].isna(),'Month']
# Out:
# 0      November 19
# 1       November 6
# 2            May 8
# 3          June 14
# 4           July 4
#           ...
# 467         May 30
# 468         Aug 08
# 469         Sep 02
# 470         Sep 13
# 471         Sep 16
# Name: Month, Length: 469, dtype: object

# %%
#assigning rows of Year column with null values to day variable created above
data_.loc[data_['Year'].isna(),'Year'] = day
#replacing any rows containing values other than alphabets with empty strings
data_1 = data_["Month"].replace('[^a-zA-z]','',regex=True)
data_1 = pd.concat([data_.drop(columns='Month'),data_1],axis=1)

# %%
data_1['Day_date'].apply(len)
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 491    2
# 492    2
# 493    1
# 494    2
# 495    2
# Name: Day_date, Length: 496, dtype: int64

# %%
year = data_1.loc[data_1['Day_date'].apply(len)>2, 'Day_date']
day = data_1.loc[data_1['Year'].apply(len)<3, 'Year']

# %%
data_1.loc[data_1['Day_date'].apply(len)>2, 'Day_date'] = day
data_1.loc[data_1['Year'].apply(len)<3, 'Year']=year

# %%
data_1
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                        ...                            ...
# 491  492   Thursday-October-05-2017           13 MuHarram 1439 A.H
# 492  493   Thursday-October-19-2017           27 MuHarram 1439 A.H
# 493  494   Thursday-November-9-2017              19 Safar 1439 A.H
# 494  495    Friday-November-24-2017       5 Rabi Al-Awwal 1439 A.H
# 495  496  Saturday-November-25-2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type         Time       City   Latitude  Longitude     Province  \
# 0          Holiday          N/A  Islamabad     33.718    73.0718      Capital
# ...

# %%
data_1.isna().sum()
# Out:
# S#                         0
# Date                       0
# Islamic Date               0
# Blast Day Type             0
# Time                       0
# City                       0
# Latitude                   0
# Longitude                  0
# Province                   0
# Location                   0
# Location Category          0
# Location Sensitivity       0
# Open/Closed Space          0
# Influencing Event/Event    0
# Target Type                0
# Targeted Sect if any       0
# Killed Min                 0
# Killed Max                 0
# Injured Min                0
# Injured Max                0
# No. of Suicide Blasts      0
# Explosive Weight (max)     0
# Hospital Names             0
# Temperature(C)             0
# Temperature(F)             0
# Holiday Type               0
# Day_name                   0
# Day_date                   0
# Year                       0
# Month                      0
# dtype: int64

# %%
#visualizing rows where Blast day type is empty  
data_1.loc[data['Blast Day Type']=='']
# Out:
#       S#                        Date Islamic Date Blast Day Type Time  \
# 413  414    Thursday-January 23-2014
# 431  432   Wednesday-October 15-2014
# 434  435    Tuesday-December 16-2014
# 435  436     Sunday-December 28-2014
# 436  437      Friday-January 30-2015
# 437  438     Friday-February 13-2015
# 438  439    Tuesday-February 17-2015
# 439  440  Wednesday-February 18-2015
# 440  441        Sunday-March 15-2015
# 441  442        Friday-March 20-2015
#
#              City Latitude Longitude     Province  \
# 413      Peshawar  34.0043   71.5448          KPK
# 431  Tirah Valley  33.8679  70.51364         FATA
# 434      Peshawar  34.0043   71.5448          KPK
# 435          Zhob    31.35     69.45  Balochistan
# 436     Shikarpur       28   68.6667        Sindh
# 437      Peshawar  34.0043   71.5448          KPK
# 438        Lahore  31.5451   74.3407       Punjab
# 439    Rawalpindi     33.6   73.0333       Punjab
# 440        Lahore  31.5451   74.3407       Punjab
# ...

# %%
data_1['City'].unique()
# Out:
# array(['Islamabad', 'Karachi', 'Quetta', 'Rawalpindi', 'North waziristan',
#        'Kohat', 'Attock', 'Sialkot', 'Lahore', 'Swat', 'Hangu', 'Bannu',
#        'North Waziristan', 'Lasbela', 'Malakand', 'Peshawar', 'D.I Khan',
#        'Lakki Marwat', 'Tank', 'Gujrat', 'Charsadda', 'Kuram Agency',
#        'Shangla', 'Bajaur Agency', 'South Waziristan', 'Haripur', 'bannu',
#        'karachi', 'Sargodha', 'Nowshehra', 'Mohmand agency',
#        'Dara Adam Khel', 'Khyber Agency', 'Mardan', 'Bhakkar',
#        'Orakzai Agency', 'Mohmand Agency', 'Buner', 'D.G Khan', 'Pishin',
#        'Chakwal', 'Upper Dir', 'Muzaffarabad', 'swat', 'Totalai',
#        'Multan', 'Lower Dir', 'Lakki marwat', 'Sudhanoti', 'peshawar',
#        'Poonch', 'Mansehra', 'Karak', 'South waziristan', 'lakki marwat',
#        'Swabi', 'Dara Adam khel', 'Shikarpur', 'Sukkur', 'Chaman',
#        'D. I Khan', 'Khanewal', 'Fateh Jang', 'Taftan', 'Tirah Valley',
# ...

# %%
#attempt to fix time column
data_1['Time'].str.replace(' ','')
# Out:
# 0             N/A
# 1             N/A
# 2          7:45AM
# 3      11:10:00AM
# 4             N/A
#           ...
# 491
# 492        8:00AM
# 493        7:00AM
# 494        7:00AM
# 495        7:00AM
# Name: Time, Length: 496, dtype: object

# %%
data_1.columns
# Out:
# Index(['S#', 'Date', 'Islamic Date', 'Blast Day Type', 'Holiday Type', 'Time',
#        'City', 'Latitude', 'Longitude', 'Province', 'Location',
#        'Location Category', 'Location Sensitivity', 'Open/Closed Space',
#        'Influencing Event/Event', 'Target Type', 'Targeted Sect if any',
#        'Killed Min', 'Killed Max', 'Injured Min', 'Injured Max',
#        'No. of Suicide Blasts', 'Explosive Weight (max)', 'Hospital Names',
#        'Temperature(C)', 'Temperature(F)', 'Day_name', 'Month', 'Year',
#        'Day_date'],
#       dtype='object')

# %%
#changing empty rows in Latitude column to 0.0 then the median of the column
data_1['Latitude'].replace('',0.0,inplace=True)
data_2 = data_1['Latitude'].replace('',data_1['Latitude'].median())
data_2 = pd.concat([data_1.drop(columns='Latitude'),data_2],axis=1)

# %%
data_1.City.unique()
# Out:
# array(['Islamabad', 'Karachi', 'Quetta', 'Rawalpindi', 'North waziristan',
#        'Kohat', 'Attock', 'Sialkot', 'Lahore', 'Swat', 'Hangu', 'Bannu',
#        'North Waziristan', 'Lasbela', 'Malakand', 'Peshawar', 'D.I Khan',
#        'Lakki Marwat', 'Tank', 'Gujrat', 'Charsadda', 'Kuram Agency',
#        'Shangla', 'Bajaur Agency', 'South Waziristan', 'Haripur', 'bannu',
#        'karachi', 'Sargodha', 'Nowshehra', 'Mohmand agency',
#        'Dara Adam Khel', 'Khyber Agency', 'Mardan', 'Bhakkar',
#        'Orakzai Agency', 'Mohmand Agency', 'Buner', 'D.G Khan', 'Pishin',
#        'Chakwal', 'Upper Dir', 'Muzaffarabad', 'swat', 'Totalai',
#        'Multan', 'Lower Dir', 'Lakki marwat', 'Sudhanoti', 'peshawar',
#        'Poonch', 'Mansehra', 'Karak', 'South waziristan', 'lakki marwat',
#        'Swabi', 'Dara Adam khel', 'Shikarpur', 'Sukkur', 'Chaman',
#        'D. I Khan', 'Khanewal', 'Fateh Jang', 'Taftan', 'Tirah Valley',
# ...

# %%
#casting Latitude column to float and rounding to 4d.p
data_2['Latitude'] = data_2['Latitude'].astype(float).round(4)
data_2['Latitude'].unique()
# Out:
# array([33.718 , 24.9918, 30.2095, 33.6058, 32.9746, 33.5833, 33.7645,
#        32.4972, 31.5451, 35.2227, 33.5351, 32.9861, 25.8377, 34.503 ,
#        34.0043, 31.8238, 32.6018, 32.5737, 34.1509, 32.226 , 34.8015,
#        34.8718, 32.3202, 34.0011, 32.0791, 34.0322, 32.935 , 33.6854,
#        34.0211, 34.1982, 31.6216, 34.3943, 35.3833, 30.05  , 30.5833,
#        32.9303, 35.1977, 34.3597, 34.2   , 30.1886, 34.8453, 33.706 ,
#        33.8243, 34.3333, 33.1193, 34.1335, 28.    , 27.6833, 30.9222,
#        30.2999, 33.5689, 28.28  , 33.8679, 31.6047, 31.35  , 33.6   ,
#        32.0836,  0.    , 33.7687, 30.1936, 24.8795, 30.7127, 30.183 ,
#        28.2747, 34.2001, 30.1657, 33.9995, 31.3413, 30.1998, 34.1494,
#        31.5129, 34.0478, 34.2079, 34.1957, 30.1942, 34.1958, 28.0027,
#        34.4003, 30.1428, 25.7768, 34.3258, 32.9498, 31.5554, 34.5   ,
#        33.9861, 34.5538, 26.4193, 34.3   , 31.463 , 29.8008, 33.3875,
# ...

# %%
#similar process done for latitude is done for longitude column
data_2['Longitude'].replace('',0.0,inplace=True)
data_3 = data_2['Longitude'].replace(0.0,data_2['Longitude'].median())
data_3 = pd.concat([data_2.drop(columns='Longitude'),data_3],axis=1)
#casting entries to float and rounding to 4d.p
data_3['Longitude'] = data_3['Longitude'].astype(float).round(4)
data_3['Longitude'].unique()
# Out:
# array([73.0718, 66.9911, 67.0182, 73.0437, 70.1456, 71.4333, 72.3667,
#        74.5361, 74.3407, 72.4258, 71.0713, 70.6042, 66.5224, 71.9046,
#        71.5448, 70.9095, 70.9148, 74.0786, 71.7359, 70.3761, 72.757 ,
#        71.5249, 69.8597, 72.9372, 72.6718, 73.0944, 70.6688, 71.5131,
#        71.2874, 72.0444, 71.065 , 72.6151, 72.1833, 70.6333, 67.    ,
#        72.8556, 71.8749, 73.4711, 72.5   , 71.4559, 73.7242, 73.7949,
#        73.2   , 71.0951, 72.4702, 68.6667, 68.8667, 66.4447, 71.9308,
#        72.6378, 62.35  , 70.5136, 74.5729, 69.45  , 73.0333, 72.6711,
#        70.1455, 72.3621, 71.449 , 67.1746, 70.6582, 66.9987, 68.7129,
#        72.0508, 67.0018, 71.425 , 69.4487, 67.0102, 71.7428, 74.289 ,
#        71.2844, 72.0495, 72.0378, 67.0088, 72.0366, 68.7304, 71.5604,
#        66.982 , 67.0224, 71.3988, 70.6091, 74.3319, 71.3333, 71.4569,
#        71.4341, 67.8594, 71.6539, 74.4357, 66.8481, 71.3404, 70.1088,
# ...

# %%
data_3['Location'].unique()
# Out:
# array(['Egyptian Embassy', 'office of Nawa-e-Waqt',
#        'Pakistan Navy bus Parked outside Five Star Sheraton Hotel',
#        'US Consulate Civil Lines Area', 'Imambargah MeCongy Road Quetta',
#        'Jhanda Chichi area rawalpindi',
#        'Yadgar-i-Hussaini in Satellite Town',
#        'Karachi Shia mosque Sindh Madrassatul Islam',
#        'Imambargah off M.A Jinnah road near Numaish intersection',
#        'checkpost in north waziristan-close to Afghanistan border',
#        'Near military facility/official Residence of General Officer Commanding',
#        'Mr Aziz election rally in jaffar village in fateh jang',
#        'zainabia mosque-just a Km away from city police station on Raja road',
#        'Jamia Masjid Kashmirian in Mochi Gate', 'Gandava Town Shrine',
#        'Baidara village of Matta-District Swat', 'Shrine of Bari Imam',
#        'Courtyard of an Imambargah(Madinatul Ilm ) in Gulshan e Iqbal',
#        'Hangu-Tall road-Ashura Procession',
# ...

# %%
#replacing new lines in Location column with space
data_3['Location'] = data_3['Location'].str.replace('\n',' ')

# %%
data_3['Location'].unique()
# Out:
# array(['Egyptian Embassy', 'office of Nawa-e-Waqt',
#        'Pakistan Navy bus Parked outside Five Star Sheraton Hotel',
#        'US Consulate Civil Lines Area', 'Imambargah MeCongy Road Quetta',
#        'Jhanda Chichi area rawalpindi',
#        'Yadgar-i-Hussaini in Satellite Town',
#        'Karachi Shia mosque Sindh Madrassatul Islam',
#        'Imambargah off M.A Jinnah road near Numaish intersection',
#        'checkpost in north waziristan-close to Afghanistan border',
#        'Near military facility/official Residence of General Officer Commanding',
#        'Mr Aziz election rally in jaffar village in fateh jang',
#        'zainabia mosque-just a Km away from city police station on Raja road',
#        'Jamia Masjid Kashmirian in Mochi Gate', 'Gandava Town Shrine',
#        'Baidara village of Matta-District Swat', 'Shrine of Bari Imam',
#        'Courtyard of an Imambargah(Madinatul Ilm ) in Gulshan e Iqbal',
#        'Hangu-Tall road-Ashura Procession',
# ...

# %%
data_3['Location Category'].unique()
# Out:
# array(['Foreign', 'Office Building', 'Hotel', 'Religious', 'Mobile',
#        'Military', 'Residence', 'Park/Ground', 'Market', 'Police',
#        'Airport', 'Government', 'Transport', 'Hospital', 'Educational',
#        'Civilian', 'Bank', 'Foreigner', 'Government/Office Building',
#        'Government Official', 'foreign', '', 'Residential Building',
#        'Commercial/residence', 'Highway'], dtype=object)

# %%
#replacing inconsistency in Location Category with space
data_3['Location Category'] = data_3['Location Category'].str.replace('/',' ')
data_4 = data_3['Location Category'].replace('','No Location')
data_4 = pd.concat([data_3.drop(columns='Location Category'),data_4],axis=1)
data_4['Location Category'].unique()
# Out:
# array(['Foreign', 'Office Building', 'Hotel', 'Religious', 'Mobile',
#        'Military', 'Residence', 'Park Ground', 'Market', 'Police',
#        'Airport', 'Government', 'Transport', 'Hospital', 'Educational',
#        'Civilian', 'Bank', 'Foreigner', 'Government Office Building',
#        'Government Official', 'foreign', 'No Location',
#        'Residential Building', 'Commercial residence', 'Highway'],
#       dtype=object)

# %%
#converting all values in Location Sensitivity column to lower case
data_4['Location Sensitivity'] = data_4['Location Sensitivity'].apply(lambda x : x.lower())

# %%
data_5 = data_4['Location Sensitivity'].replace('','None')
data_5 = pd.concat([data_4.drop(columns='Location Sensitivity'),data_5],axis=1)

# %%
data_5.columns
# Out:
# Index(['S#', 'Date', 'Islamic Date', 'Blast Day Type', 'Time', 'City',
#        'Province', 'Location', 'Open/Closed Space', 'Influencing Event/Event',
#        'Target Type', 'Targeted Sect if any', 'Killed Min', 'Killed Max',
#        'Injured Min', 'Injured Max', 'No. of Suicide Blasts',
#        'Explosive Weight (max)', 'Hospital Names', 'Temperature(C)',
#        'Temperature(F)', 'Holiday Type', 'Day_name', 'Day_date', 'Year',
#        'Month', 'Latitude', 'Longitude', 'Location Category',
#        'Location Sensitivity'],
#       dtype='object')

# %%
data_5['Open/Closed Space'].unique()
# Out:
# array(['Closed', 'Open', 'open', '', 'closed', 'Open/Closed'],
#       dtype=object)

# %%
#taking all to lower case then replacing certain input with new categories
data_5['Open/Closed Space'] = data_5['Open/Closed Space'].apply(lambda x : x.lower())
data_6 = data_5['Open/Closed Space'].replace(['','open/closed'],['None','indecisive'])
data_6 = pd.concat([data_5.drop(columns='Open/Closed Space'),data_6],axis=1)

# %%
data_6['Open/Closed Space'].unique()
# Out:
# array(['closed', 'open', 'None', 'indecisive'], dtype=object)

# %%
data_6['Influencing Event/Event'].unique()
# Out:
# array(['', 'during Friday prayer',
#        "president's/chief of army staff convoy passing from there",
#        'maghrib prayer was in process', 'Friday prayer was in progress',
#        'Army', 'Election rally', 'Friday prayer',
#        'Jamia Masjid /Shia Mosque', 'Urs Ceremony', 'NA',
#        'Shia Muslim Annual \nCongregation ', 'evening prayer',
#        'Ashura Day',
#        'Terrorists attacked convoy of david foy-american diplomat.',
#        'Eid Miladun Nabi', 'Army convoy', 'Recruits parade', 'police van',
#        'Military convoy', 'Indian High Commission Function',
#        'Muharram procession about to start', 'Muharram procession',
#        'Rally Charsadda', 'rammed the vehicle into FC vehicle',
#        'Frontier Constabulary convoy', 'recruitment process in progress',
#        'police bus going from Kabal to Matta',
#        'Chief Justice Iftikhar muhammad ch had to address overthere',
#        'chinese engineers were going from Karachi to Hub',
# ...

# %%
data_6['Influencing Event/Event'][5:]
# Out:
# 5      president's/chief of army staff convoy passing...
# 6                          maghrib prayer was in process
# 7                          Friday prayer was in progress
# 8
# 9
#                              ...
# 491                            at the entrance of shrine
# 492    explosives-laden vehicle rammed into a securit...
# 493                           AIG Hamid Shakil’s vehicle
# 494                 a police vehicle of AIG Asharf Noor
# 495    transport for a colonel in Pakistan's armed fo...
# Name: Influencing Event/Event, Length: 491, dtype: object

# %%
#replacing any row in column not containing characters listed in the bracket with space
data_7  = data_6['Influencing Event/Event'].replace("[^a-zA-Z0-9'-]",' ',regex=True)
data_7 = pd.concat([data_6.drop(columns='Influencing Event/Event'),data_7],axis=1)

# %%
#Creating No Desc category for empty entries in column
data_8 = data_7['Influencing Event/Event'].where(data_7['Influencing Event/Event']!='','No Desc')
data_8 = pd.concat([data_7.drop(columns='Influencing Event/Event'),data_8],axis=1)
data_8['Influencing Event/Event']
# Out:
# 0                                                No Desc
# 1                                                No Desc
# 2                                                No Desc
# 3                                                No Desc
# 4                                   during Friday prayer
#                              ...
# 491                            at the entrance of shrine
# 492    explosives-laden vehicle rammed into a securit...
# 493                           AIG Hamid Shakil s vehicle
# 494                 a police vehicle of AIG Asharf Noor
# 495    transport for a colonel in Pakistan's armed fo...
# Name: Influencing Event/Event, Length: 496, dtype: object

# %%
data_8['Target Type'].unique()
# Out:
# array(['Foreigner', 'Media', 'Religious', 'Military',
#        'Government Official', 'civilian', 'Civilian', 'Police',
#        'Government official', 'police', 'Children/Women',
#        'Anti-Militants', 'foreigner', 'Unknown', 'religious', '',
#        'Rangers', 'Police & Rangers', 'Civilian & Police', 'Army',
#        'Frontier Corps', 'advocates (lawyers)', 'Civilian Judges',
#        'Shia sect', 'Judges & lawyers'], dtype=object)

# %%
#fixing inconsistency in Target Type column
data_8['Target Type'].replace('[/&()]',' ',regex=True,inplace=True)
#replacing empty entries with new category 'None'
data_8['Target Type'].replace('','None',inplace=True)
#reducing large spaces in entries
data_8['Target Type'] = data_8['Target Type'].str.replace('   ',' ')
data_9 = data_8['Target Type'].replace('-',' ')
data_9 = pd.concat([data_8.drop(columns='Target Type'),data_9],axis=1)

# %%
#replacing empty entries with None category
data_9['Targeted Sect if any'].replace('','None',inplace=True)
#setting all entries in column to lower case
data_9['Targeted Sect if any'] = data['Targeted Sect if any'].apply(lambda x:x.lower())
#replacing na entries in column with none as they virtually mean same thing
data_10 = data_9['Targeted Sect if any'].replace('na','none')
data_10 = pd.concat([data_9.drop(columns='Targeted Sect if any'),data_10],axis=1)
#rows where entries are not clear(entering double entries) are set as none
data_10.loc[data['Targeted Sect if any']=='shiite/sunni','Targeted Sect if any']='none'
data_10['Targeted Sect if any'].unique()
# Out:
# array(['none', 'christian', 'shiite', 'shiite/sunni', 'sunni', 'jews', '',
#        'ahmedi'], dtype=object)

# %%
data_10['Targeted Sect if any'].unique()
# Out:
# array(['none', 'christian', 'shiite', 'shiite/sunni', 'sunni', 'jews', '',
#        'ahmedi'], dtype=object)

# %%
data_10.columns
# Out:
# Index(['S#', 'Date', 'Islamic Date', 'Blast Day Type', 'Time', 'City',
#        'Province', 'Location', 'Killed Min', 'Killed Max', 'Injured Min',
#        'Injured Max', 'No. of Suicide Blasts', 'Explosive Weight (max)',
#        'Hospital Names', 'Temperature(C)', 'Temperature(F)', 'Holiday Type',
#        'Day_name', 'Day_date', 'Year', 'Month', 'Latitude', 'Longitude',
#        'Location Category', 'Location Sensitivity', 'Open/Closed Space',
#        'Influencing Event/Event', 'Target Type', 'Targeted Sect if any'],
#       dtype='object')

# %%
data_10['Killed Min'].unique()
# Out:
# array([14, '', 13, 44, 16, 2, 25, 4, 20, 5, 37, 47, 6, 40, 1, 22, 8, 23,
#        17, 28, 15, 9, 3, 18, 125, 7, 10, 21, 24, 38, 26, 11, 30, 70, 34,
#        12, 48, 35, 32, 36, 88, 43, 50, 41, 80, 65, 27, 54, 61, 42, 82, 0,
#        51, 64, 78, 45, 60, 58], dtype=object)

# %%
#replace empty strings with 0.0
data_11 = data_10['Killed Min'].replace('',0.0)
data_11 = pd.concat([data_10.drop(columns='Killed Min'),data_11],axis=1)
#casting to integer type
data_11['Killed Min'] = data_11['Killed Min'].astype(int)
data_11['Killed Min'].unique()
# Out:
# array([ 14,   0,  13,  44,  16,   2,  25,   4,  20,   5,  37,  47,   6,
#         40,   1,  22,   8,  23,  17,  28,  15,   9,   3,  18, 125,   7,
#         10,  21,  24,  38,  26,  11,  30,  70,  34,  12,  48,  35,  32,
#         36,  88,  43,  50,  41,  80,  65,  27,  54,  61,  42,  82,  51,
#         64,  78,  45,  60,  58])

# %%
#replacing empty string with 0
data_12 = data_11['Injured Min'].replace('',0)
data_12 = pd.concat([data_11.drop(columns='Injured Min'),data_12],axis=1)
data_12['Injured Min'].unique()
# Out:
# array([  0,  20,   3,  96,  44,  50,   6,   8,  82,  19,  90,  30,   7,
#         23,   5,  29,  12,   9,   4,  26,  40,   2,  28,  35,  14,  22,
#         16,  11, 100,  18,  27,  48,  73,  13, 109,  15, 175,  17,  10,
#         25,  33,  67,  70, 200,  60,  21,  31, 150, 320,  63, 148,  45,
#         47,  46,  75,  37,  55,  24,   1,  81,  80,  52,  92, 104,  34,
#         71, 128,  41,  39, 116, 180,  49,  65,  36,  32, 233, 112,  83,
#         56], dtype=int64)

# %%
data_12['Injured Max'].unique()
# Out:
# array([60, 3, 40, 51, 65, 50, 4, 200, 35, 2, 70, 75, 10, 100, '', 30, 54,
#        8, 26, 0, 39, 1, 25, 7, 12, 29, 61, 47, 58, 6, 43, 5, 18, 37, 9,
#        19, 46, 32, 550, 31, 22, 23, 20, 13, 80, 15, 110, 24, 11, 55, 90,
#        300, 27, 14, 45, 16, 175, 48, 36, 370, 105, 120, 187, 17, 83, 135,
#        41, 49, 243, 57, 77, 132, 140, 52, 42, 114, 107, 130, 82, 28, 33,
#        21, 121, 68, 145, 34, 72,
#        'http://www.samaa.tv/pakistan/29-Jun-2015/shootout-after-suicide-attack-in-lahore',
#        56, '40+', 165, '100+'], dtype=object)

# %%
#using regex to replace anything not number to empty string
data_12['Injured Max'].replace('[^0-9]','',regex=True,inplace=True)
data_12['Injured Max'].replace('',0,inplace=True)
#casting to int
data_12['Injured Max'] = data_12['Injured Max'].astype(int)
#after applying regex a certain link function gave unexpected output, line deals with this output
data_13 = data_12['Injured Max'].where(data_12['Injured Max']!=292015,data_12['Injured Max'].median())
data_13 = pd.concat([data_12.drop(columns='Injured Max'),data_13],axis=1)

# %%
data_13['No. of Suicide Blasts'].unique()
# Out:
# array([2, 1, '', 'N/A', 3, 4], dtype=object)

# %%
data_14 = data_13['No. of Suicide Blasts'].replace(['','N/A'],[np.nan,np.nan])
data_14 = pd.concat([data_13.drop(columns='No. of Suicide Blasts'),data_14],axis=1)

# %%
data_14['Hospital Names'].unique()
# Out:
# array(['',
#        '1.Jinnah Postgraduate Medical Center 2. Civil Hospital Karachi 3. PN Shifa',
#        'NA', '1.CMH Quetta \n2.Civil Hospital 3. Boland Medical Complex',
#        '1.District headquarters \nHospital ', 'Civil hospital',
#        'Civil hospital-Liaquat National hospital-Jinnah Postgraduate Medical Center',
#        'CMH Kohat',
#        '1.District Headquarters hospital-rwp 2.PIMS Hospital 3. Tehsil headquarters hospital-Fateh Jang',
#        'Allama Iqbal Memorial DHQ Hospital-Sardar Begum Hospital-and numner of other hospitals in Sialkot-Daska-Gujranwala and Lahore',
#        'Mayo Hospital',
#        '1. PIMS 2.Polyclinic 3.CDA Hospital 4.federal govt services 5.rwp generl hosp',
#        '1. Patel Hospital 2. JMPC', 'Hangu Hospital',
#        '1. Liaquat National Hospital 2. Civil Hospital KHI 3. JPMC 4. Abbasi Shaheed Hospital',
#        '1. Combined Military 2. Hospital Peshawar',
#        '1. CMH Mardan\n2. CMH Peshawar', '1.poly Clinic Hospital',
# ...

# %%
data_14['Hospital Names'].replace("[^a-zA-Z0-9']",' ',regex=True,inplace=True)
data_15 = data_14['Hospital Names'].replace(np.nan,0)
data_15 = pd.concat([data_14.drop(columns='Injured Max'),data_15],axis=1)

# %%
data_15['Temperature(C)']=data_15['Temperature(C)'].replace('',np.nan).round(3)
data_15['Temperature(F)']=data_15['Temperature(F)'].replace('',np.nan).round(3)

# %%
data_15['Temperature(F)'].unique()
# Out:
# array([ 60.503,  74.786,  88.628,  88.574,  91.616,  49.001,  59.495,
#         92.948,  88.889,  80.924,  90.374,  79.997,  81.518,  75.902,
#         61.7  ,  67.883,  80.888,  89.501,  59.891,  77.54 ,  83.147,
#         79.025,  83.498,  81.5  ,  66.569,  63.095,  40.469,  36.185,
#         61.34 ,  59.297,  63.941,  63.536,  61.943,  47.696,  78.071,
#         82.499,  87.98 ,  76.883,  80.555,  89.132,  88.502,  78.836,
#         83.876,  81.059,  83.975,  80.501,  90.311,  87.323,  86.495,
#         83.075,  79.502,  82.418,  78.503,  79.133,  84.218,  85.937,
#         80.951,  83.057,  81.455,  83.912,  85.244,  80.87 ,  87.467,
#         76.469,  76.226,  82.445,  69.845,  69.629,  69.476,  67.001,
#         59.999,  58.514,  53.465,  53.834,  39.488,  49.127,  52.421,
#         59.   ,  54.968,  50.378,  44.186,  57.002,  41.261,  54.212,
#         36.455,  47.156,  27.734,  46.283,  36.041,  54.905,  58.046,
# ...

# %%
data['Time'].replace('[^0-9:a-zA-Z]',' ',regex=True,inplace=True)

# %%
data['Time'].unique()
# Out:
# array(['N A', '7:45 AM', '11:10:00 AM', '1:40:00 PM 1:42:00 PM', '',
#        '1:20:00 1:17:00 PM', 'evening', '8:50:PM', '7:20 PM',
#        '1:27 PM 1:25 PM', '5:55:00 6:40:00 PM', '11 45PM  10 30 pm',
#        '11:00:00 AM', '9:35:00 AM', '9:00:00 AM', '7 00 pm', '10 30 am',
#        '3:30:00 PM', '8 00 am', '8 30am', '7 30 am 7:15AM', '10:30:00 AM',
#        '2:37:00 PM', '8:40:00 PM', '6:17:00 AM', '12:15:00 PM',
#        '8:50:00 PM 9:10 PM', '11:05:00 AM', '11:45 AM', '6:55 PM',
#        '12:55:00 PM', 'About 12pm', '10:25am', '4:30:00 PM', '2:00:00 PM',
#        '3:30 PM 4:00:00 PM 4:15PM', 'between 7:00 7:40 AM', '8:27:00 AM',
#        '1:30:00 PM', '8:40:00 AM', '7:50:00 AM', '12:30:00 PM 11:00AM',
#        '5:25 PM', 'Night', '10:30am', 'NA', '10:00:00 AM', '7:15:00 AM',
#        '7:15:00 PM', '2:00:00 AM', '8:30:00 AM', '12:00 mid night',
#        '2:45:00 PM', '11:50:00 AM', '7:10:00 AM', '4:15:00 PM',
#        '7:40:00 AM', '11:15:00 AM 12:30 PM', '7:24:00 AM 7:30AM',
# ...

# %%
data.to_csv("consistent1.csv",index=False)
